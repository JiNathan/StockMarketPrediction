# %% [markdown]
# Load Data from stocks.json
#
# Source code: stocks_api.ipynb

# %%
# imports
import json
import pandas as pd
import numpy as np
import datetime

# %%
def convert_to_dates(date_list: list[str]) -> np.array:
    # [datetime.datetime.fromisoformat(date_str) for date_str in date_list]
    return np.array([datetime.datetime.fromisoformat(date_str).replace(tzinfo=None) for date_str in date_list])

def from_json(file_name) -> pd.DataFrame:
    with open(file_name, "r") as f:    
       ret_val = pd.json_normalize(json.load(f))
    ret_val['dates'] = ret_val['dates'].apply(lambda date_list: convert_to_dates(date_list))
    ret_val['prices'] = ret_val['prices'].apply(lambda price_list: np.array(price_list))
    return ret_val

# %%
# # USAGE
# hold = from_json("stocks.json")
# # TEST
# print(hold.iloc[0]["prices"])
hold
# Out:
# ['174.78999' '174.11000' '173.85001' ... '83.67000' '82.50000' '83.02000']
#     ticker                                             prices  \
# 0      MMM  [174.78999, 174.11000, 173.85001, 174.71001, 1...
# 1      AOS  [54.82000, 54.71000, 54.71000, 55.62000, 55.48...
# 2      ABT  [109.49000, 108.44000, 108.33000, 107.79000, 1...
# 3     ABBV  [107.15000, 105.27000, 104.70000, 103.45000, 1...
# 4      ACN  [261.20999, 257.54001, 257.76001, 259.67999, 2...
# ..     ...                                                ...
# 494    YUM  [108.56000, 109.51000, 109.45000, 109.78000, 1...
# 495   ZBRA  [384.32999, 383.75000, 378.04001, 382.59000, 3...
# 496    ZBH  [149.48625, 147.67212, 147.89525, 144.44162, 1...
# 497   ZION  [43.44000, 43.22000, 42.77000, 43.36000, 43.34...
# 498    ZTS  [165.50000, 164.27000, 163.12000, 162.39000, 1...
#
#                                                  dates                industry
# 0    [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...             Industrials
# 1    [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...             Industrials
# 2    [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...             Health Care
# 3    [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...             Health Care
# 4    [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...  Information Technology
# ..                                                 ...                     ...
# 494  [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...  Consumer Discretionary
# 495  [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...  Information Technology
# 496  [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...             Health Care
# 497  [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...              Financials
# 498  [2020-12-31 00:00:00, 2020-12-30 00:00:00, 202...             Health Care
#
# [499 rows x 4 columns]
